# %% [markdown]
# # <b>МОДЕЛЬ 1</b> | `Include_top`

# %% [markdown]
# ## Модуль `tf.keras.applications` | `feature_extractor_layer`

# %% [markdown]
# Создадим `feature_extractor`, который извлечет веса из предобученной модели `tensorflow` для переноса обучения на нашу модель. При переносе обучения рекомендуется отключать самые "верхние", то есть последние слои предобученной модели: именно в них происходит обучение на данную классификацию. Однако для начала мы проверим, как будут обучаться наши модели на полной предобученной модели `Mobile Net V2`.
#
# Во втором блоке экспериментов мы отключим верхние слои, а в третьем пойдем еще дальше и разморозим часть слоев предобученной модели. За "разморозку" слоев у нас будет отвечать параметр `do_fine_tuning`, который может принимать только булевы значения (в первых двух блоках он установлен в режим `False`).
#
# Итак, приступим к первому блоку экспериментов, используем предобученную модель "как есть".

# %%
do_fine_tuning = False
feature_extractor = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=True,
                                               weights='imagenet')
feature_extractor.trainable = do_fine_tuning

print(f'Разморозка слоев: {do_fine_tuning}.')
# Out:
# Разморозка слоев: False.

# %% [markdown]
# ## <b>Модель 1.1</b> | Baseline

# %% [markdown]
# Построим базовую последовательную модель, в которой у нас будут только слои `rescale`,  `feature_extractor` и слой предсказания.

# %% [markdown]
# ### Архитектура модели

# %%
print(f'Строим модель на базе {MODULE_HANDLE}.')
print(f'Разморозка слоев: {do_fine_tuning}.\n')

model = tf.keras.Sequential([
            rescale,
            data_aug,
            feature_extractor,
            tf.keras.layers.Dropout(DROPOUT_RATE),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(num_classes, activation='softmax')
], name='model_11')

model.summary()
# Out:
# Строим модель на базе tf.keras.applications.MobileNetV2.
# Разморозка слоев: False.
#
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  mobilenetv2_1.00_224 (Funct  (None, 1000)             3538984
#  ional)
#
#  dropout_22 (Dropout)        (None, 1000)              0
#
#  batch_normalization_34 (Bat  (None, 1000)             4000
#  chNormalization)
#
#  dense_42 (Dense)            (None, 64)                64064
#
#  batch_normalization_35 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_43 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 3,607,629
# Trainable params: 66,517
# Non-trainable params: 3,541,112
# _________________________________________________________________

# %% [markdown]
# Проверим количество обучаемых параметров. Два означает - вектор значений весов (kernel) и вектор значений свободных членов (bias).

# %%
len(model.trainable_variables)
# Out:
# 8

# %% [markdown]
# ### Компиляция

# %% [markdown]
# В качестве оптимизатора во всех моделях неизменно будем использовать Adam, learning_rate установим базовый, он будет корректироваться как самим оптимизатором внутри эпохи, так и в начале каждой эпохи благодаря `lr_schedule` `callback`.

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=BASE_LR),
              loss='categorical_crossentropy',
              metrics=metrics)

# %% [markdown]
# Модель скомпилирована, то есть все заданные параметры зафиксированы до следующей компиляции.

# %% [markdown]
# ### Обучение модели

# %% [markdown]
# На стадии обучения модели зададим зафиксированное количество эпох (500), которое в процессе обучения будет автоматически оптимизировано соответствующим callback'ом.

# %%
hist = model.fit(train_batches,
                 epochs=EPOCHS,
                 validation_data=validation_batches,
                 callbacks=[early_stopping, lr_schedule]
                )
# Out:
# Epoch 1/500
# 34/34 [==============================] - 57s 2s/step - loss: 1.8470 - accuracy: 0.2685 - PR_AUC: 0.2504 - val_loss: 1.5977 - val_accuracy: 0.2642 - val_PR_AUC: 0.2392 - lr: 0.0100
# Epoch 2/500
# 34/34 [==============================] - 60s 2s/step - loss: 1.5336 - accuracy: 0.3593 - PR_AUC: 0.3581 - val_loss: 1.5869 - val_accuracy: 0.2453 - val_PR_AUC: 0.2615 - lr: 0.0100
# Epoch 3/500
# 34/34 [==============================] - 50s 1s/step - loss: 1.3947 - accuracy: 0.4250 - PR_AUC: 0.4278 - val_loss: 1.5794 - val_accuracy: 0.2767 - val_PR_AUC: 0.2878 - lr: 0.0100
# Epoch 4/500
# 34/34 [==============================] - 59s 2s/step - loss: 1.3417 - accuracy: 0.4417 - PR_AUC: 0.4667 - val_loss: 1.5709 - val_accuracy: 0.2642 - val_PR_AUC: 0.2875 - lr: 0.0100
# Epoch 5/500
# 34/34 [==============================] - 52s 2s/step - loss: 1.2809 - accuracy: 0.4657 - PR_AUC: 0.5037 - val_loss: 1.5619 - val_accuracy: 0.3019 - val_PR_AUC: 0.2983 - lr: 0.0100
# Epoch 6/500
# 34/34 [==============================] - 59s 2s/step - loss: 1.2369 - accuracy: 0.4991 - PR_AUC: 0.5377 - val_loss: 1.5562 - val_accuracy: 0.3082 - val_PR_AUC: 0.3004 - lr: 0.0100
# Epoch 7/500
# 34/34 [==============================] - 57s 2s/step - loss: 1.2015 - accuracy: 0.5130 - PR_AUC: 0.5602 - val_loss: 1.5455 - val_accuracy: 0.2893 - val_PR_AUC: 0.3149 - lr: 0.0100
# Epoch 8/500
# 34/34 [==============================] - 67s 2s/step - loss: 1.1726 - accuracy: 0.5454 - PR_AUC: 0.5827 - val_loss: 1.5294 - val_accuracy: 0.2956 - val_PR_AUC: 0.3315 - lr: 0.0100
# Epoch 9/500
# 34/34 [==============================] - 56s 2s/step - loss: 1.1516 - accuracy: 0.5444 - PR_AUC: 0.5935 - val_loss: 1.5266 - val_accuracy: 0.3019 - val_PR_AUC: 0.3233 - lr: 0.0100
# Epoch 10/500
# 34/34 [==============================] - 61s 2s/step - loss: 1.1079 - accuracy: 0.5806 - PR_AUC: 0.6270 - val_loss: 1.5163 - val_accuracy: 0.3082 - val_PR_AUC: 0.3192 - lr: 0.0100
# Epoch 11/500
# 34/34 [==============================] - 52s 2s/step - loss: 1.1009 - accuracy: 0.5537 - PR_AUC: 0.6226 - val_loss: 1.5031 - val_accuracy: 0.3333 - val_PR_AUC: 0.3237 - lr: 0.0100
# Epoch 12/500
# 34/34 [==============================] - 61s 2s/step - loss: 1.0654 - accuracy: 0.5889 - PR_AUC: 0.6519 - val_loss: 1.5067 - val_accuracy: 0.3459 - val_PR_AUC: 0.3091 - lr: 0.0100
# Epoch 13/500
# 34/34 [==============================] - 51s 2s/step - loss: 1.0457 - accuracy: 0.5954 - PR_AUC: 0.6675 - val_loss: 1.5033 - val_accuracy: 0.3648 - val_PR_AUC: 0.3180 - lr: 0.0050
# Epoch 14/500
# 34/34 [==============================] - 56s 2s/step - loss: 1.0181 - accuracy: 0.6204 - PR_AUC: 0.6952 - val_loss: 1.4913 - val_accuracy: 0.3836 - val_PR_AUC: 0.3356 - lr: 0.0025
# Epoch 15/500
# 27/34 [======================>.......] - ETA: 8s - loss: 1.0103 - accuracy: 0.6204 - PR_AUC: 0.6981
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[220], line 1
# ----> 1 hist = model.fit(train_batches,
#       2                  epochs=EPOCHS,
#       3                  validation_data=validation_batches,
#       4                  callbacks=[early_stopping, lr_schedule]
#       5                 )
#
# File C:\Python\venv\venv38\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\Python\venv\venv38\lib\site-packages\keras\engine\training.py:1384, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1377 with tf.profiler.experimental.Trace(
#    1378     'train',
#    1379     epoch_num=epoch,
#    1380     step_num=step,
#    1381     batch_size=batch_size,
#    1382     _r=1):
#    1383   callbacks.on_train_batch_begin(step)
# -> 1384   tmp_logs = self.train_function(iterator)
#    1385   if data_handler.should_sync:
#    1386     context.async_wait()
#
# File C:\Python\venv\venv38\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\Python\venv\venv38\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File C:\Python\venv\venv38\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File C:\Python\venv\venv38\lib\site-packages\tensorflow\python\eager\function.py:2956, in Function.__call__(self, *args, **kwargs)
#    2953 with self._lock:
#    2954   (graph_function,
#    2955    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956 return graph_function._call_flat(
#    2957     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File C:\Python\venv\venv38\lib\site-packages\tensorflow\python\eager\function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1849 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1850 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1851     and executing_eagerly):
#    1852   # No tape is watching; skip to running the function.
# -> 1853   return self._build_call_outputs(self._inference_function.call(
#    1854       ctx, args, cancellation_manager=cancellation_manager))
#    1855 forward_backward = self._select_forward_and_backward_functions(
#    1856     args,
#    1857     possible_gradient_type,
#    1858     executing_eagerly)
#    1859 forward_function, args_with_tangents = forward_backward.forward()
#
# File C:\Python\venv\venv38\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File C:\Python\venv\venv38\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Визуализация данных по работе алгоритма

# %%
val_acc_viz(hist, len(hist.history['accuracy']))

# %% [markdown]
# ### Предсказание модели

# %% [markdown]
# #### На изображениях из Сети

# %% [markdown]
# При желании качество работы модели можно проверить на реальных фотографиях экспертным методом. Для этого создадим новую папку, куда загрузим желаемые изображения. Далее, подготовленная функция преобразует изображения в необходимый для визуализации и предсказания формат. Оставим эту часть в качестве дополнения, использовать ее пока не будем.

# %%
# from PIL import Image
# import numpy as np
# from tensorflow.keras.utils import load_img, img_to_array
# import os

# new_test_dir = Path('./data/test_images')
# Path.mkdir(new_test_dir)

# def show_predictions(model):
    
#     images = os.listdir(new_test_dir)
    
#     for i, img_path in enumerate(images):

#         # путь к тестовым изображениям
#         path = new_test_dir / img_path

#         # приведение изображений к желаемому разрешению
#         img = load_img(path, target_size=IMAGE_SIZE + (3,))
#         # перевод изображения в массив
#         x = img_to_array(img)

#         # добавление четвертого измерения для модели
#         images = np.expand_dims(x, axis=0)
        
#         plt.figure(figsize=(2, 2))
#         # Отключить оси
#         plt.axis(False)
#         plt.imshow(np.squeeze(images).astype('uint8'))
#         # plt.title(img_path)
#         plt.show()

#         # предсказание
#         classes = model.predict(images, batch_size=10)

#         class_pred = np.argmax(classes)
#         # print(np.argmax(class_pred))
#         print(f'{img_path} is {class_names[class_pred]} ({np.max(classes[0])*100:.2f}%)')
        
# show_predictions(model)

# %% [markdown]
# #### На изображениях из тестовой выборки

# %% [markdown]
# Посмотрим на то, как модель предсказывает тестовые изображения, хранящиеся в третьей, тестовой выборке, которая до этого момента не принимала участия в работе. Напомним, что тестовая выбора разбита на батчи по одному изображению, что позволяет нам проще контролировать количество изображений, которое мы хотим использовать для предсказания. Следующая функция покажет изображение, заданное и предсказанное значение класса, а также "уверенность" модели в своем предсказании. На данном этапе посмотрим на небольшое количество изображений (по умолчанию 10, можно изменить это число, задав соответствующий аргумент), а полную картину оценим дальше, построив матрицу ошибок.

# %%
import numpy as np
from tensorflow.keras.utils import load_img, img_to_array
import os

def show_predictions(model, image_set=test_batches,
                     images_number=10, visualization=False):

    images = image_set.take(images_number)

    for img, label in images:

        if visualization == True:
            plt.figure(figsize=(2, 2))
            # Отключить оси
            plt.axis(False)
            # оставим три измерения из четырех
            image = np.squeeze(img)
            plt.imshow(image.astype('uint8'))
            plt.show()

        # реальный класс
        label = np.argmax(label)
        # предсказанный класс
        prediction = model.predict(img)
        pred = np.argmax(prediction)

        print(f'{class_names[label]} is {class_names[pred]} ({np.max(prediction[0])*100:.2f}%)')

# %%
show_predictions(model, visualization=False)
# Out:
# neutral is disgust (30.62%)
# neutral is neutral (70.08%)
# neutral is neutral (93.90%)
# fear is fear (56.81%)
# joyfulness is joyfulness (35.87%)
# joyfulness is joyfulness (29.68%)
# anger is joyfulness (34.31%)
# disgust is anger (24.19%)
# neutral is neutral (57.09%)
# fear is neutral (32.72%)

# %% [markdown]
# ### Матрица ошибок

# %% [markdown]
# Напишем функцию для отображения матрицы ошибок, которая пригодится нам и в дальнейшем.

# %%
def confusion_matrix(model, images_number=None, dataset=test_batches, class_names=class_names):

    '''
    Выводит матрицу ошибок на тестовых данных. 
    
    Аргументы:
    - model - обученная модель.
    - images_number - количество изображений из тестовой выборки;
            если None, то используются все изображения в выборке.
    - dataset - tf.dataset с тестовыми изображениями.
    '''
    
    from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

    if images_number is None:
        test_images = dataset
    else:
        test_images = dataset.take(images_number)
        
    y_test, y_pred = ([np.argmax(y) for _, y in test_images], 
                      [np.argmax(x) for x in model.predict(test_images)])
        
    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot()
    plt.show()

# %%
confusion_matrix(model)

# %% [markdown]
# ### Вывод

# %% [markdown]
# Модель удивительно устойчива к переобучению без каких-либо дополнительных слоев, но при этом и к обучению она практически неспособна. Матрица ошибок показывает, что данная модель с трудом обучается отдельным классам.
#
# Зафиксируем ее лучший показатель `val_accuracy` и попробуем улучшить модель.

# %%
val_acc_best = np.max(hist.history['val_accuracy'])
baseline_best_result = round(val_acc_best, 2)
baseline_best_result
# Out:
# 0.38

# %%
# сохраним данные о модели
model_1_1 = model
hist_1_1 = hist

# %% [markdown]
# ## <b>Модель 1.2</b> | Deeper baseline

# %% [markdown]
# Так как базовая модель очень устойчива к переобучению, но при этом обучается крайне медленно, есть смысл попробовать углубить модель (добавить полносвязных слоев) и расширить ее (увеличить количество обучаемых параметров в полносвязных слоях).

# %% [markdown]
# ### Архитектура модели

# %%
print(f'Строим модель на базе {MODULE_HANDLE}.')
print(f'Разморозка слоев: {do_fine_tuning}.\n')

model = tf.keras.Sequential([

            rescale,

            feature_extractor,

            tf.keras.layers.Dense(512, activation='relu'),
            tf.keras.layers.Dense(1024, activation='relu'),
            tf.keras.layers.Dense(1024, activation='relu'),
            tf.keras.layers.Dense(num_classes, activation='softmax')

], name='deeper_baseline')

model.build(input_shape=(None,) + IMAGE_SIZE + (3,))
model.summary()

# %%
len(model.trainable_variables)

# %% [markdown]
# ### Компиляция

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=BASE_LR),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# ### Обучение модели

# %%
hist = model.fit(train_batches,
                 epochs=EPOCHS,
                 validation_data=validation_batches,
                 callbacks=[early_stopping, lr_schedule]
                )

# %% [markdown]
# ### Визуализация данных по работе алгоритма

# %%
val_acc_viz(hist, len(hist.history['accuracy']))

# %% [markdown]
# ### Предсказание модели

# %%
show_predictions(model)

# %% [markdown]
# ### Матрица ошибок

# %%
confusion_matrix(model)

# %% [markdown]
# ### Вывод

# %% [markdown]
# Модель очень быстро переобучилась, практически с первых эпох, при этом показатели удалось несколько улучшить. Анализ матрицы ошибок показывает, что лучше всего модель предсказывает класс `neutral`, что неудивительно, так как именно в данном классе у нас больше всего изображений.
#
# Зафиксируем лучший показатель `val_accuracy` и сохраним данные по результатам работы модели в отдельные переменные на случай, если потребуется к ним снова обратиться.

# %%
val_acc_best = np.max(hist.history['val_accuracy'])
model_1_2_best_result = round(val_acc_best, 2)
model_1_2_best_result

# %%
# сохраним данные о модели
model_1_2 = model
hist_1_2 = hist

# %% [markdown]
# ## <b>Модель 1.3</b> | Dropout и BatchNormalization layers

# %% [markdown]
# Доработаем предыдущую модель, добавив в ее архитектуру аугментацию данных и слои батч-нормализации и `dropout`. Это позволит нам отложить момент переобучения.

# %% [markdown]
# ### Архитектура модели

# %%
print(f'Строим модель на базе {MODULE_HANDLE}.')
print(f'Разморозка слоев: {do_fine_tuning}.\n')

model = tf.keras.Sequential([

            rescale,
            data_aug,

            feature_extractor,

            tf.keras.layers.Dropout(DROPOUT_RATE),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(512, activation='relu'),

            tf.keras.layers.Dropout(DROPOUT_RATE),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(1024, activation='relu'),

            tf.keras.layers.Dropout(DROPOUT_RATE),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(1024, activation='relu'),

            tf.keras.layers.Dropout(DROPOUT_RATE),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(num_classes, activation='softmax')

], name='deeper_DropOut_BN_baseline')

model.build(input_shape=(None,) + IMAGE_SIZE + (3,))
model.summary()

# %%
len(model.trainable_variables)

# %% [markdown]
# ### Компиляция

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=BASE_LR),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# ### Обучение модели

# %%
hist = model.fit(train_batches,
                 epochs=EPOCHS,
                 validation_data=validation_batches,
                 callbacks=[early_stopping, lr_schedule]
                )

# %% [markdown]
# ### Визуализация данных по работе алгоритма

# %%
val_acc_viz(hist, len(hist.history['accuracy']))

# %% [markdown]
# ### Предсказание модели

# %%
show_predictions(model)

# %% [markdown]
# ### Матрица ошибок

# %%
confusion_matrix(model)

# %% [markdown]
# ### Вывод

# %% [markdown]
# Модель очень быстро переобучилась, практически с первых эпох, при этом и ее предсказательная способность значительно выросла. Анализ матрицы ошибок показывает, что лучше всего модель предсказывает класс `neutral`, что неудивительно, так как именно в данном классе у нас больше всего изображений. Зафиксируем лучший показатель `val_accuracy` и сохраним данные по результатам работы модели в отдельные переменные на случай, если потребуется к ним снова обратиться.

# %%
val_acc_best = np.max(hist.history['val_accuracy'])
model_1_3_best_result = round(val_acc_best, 2)
model_1_3_best_result

# %%
# сохраним данные о модели
model_1_3 = model
hist_1_3 = hist

# %% [markdown]
# # <b>МОДЕЛЬ 2</b> | Bottleneck

# %% [markdown]
# ## Модуль `tf.keras.applications` | `feature_extractor_layer`

# %% [markdown]
# Во втором блоке экспериментов будем работать с предобученной моделью, у которой отключены самые верхние слои на классификацию, цель: дообучить собственный классификатор.
#
# Выбрав опцию `include_top=False` мы оставляем для нашей модели все слои до самого последнего перед слоем `Flatten` предобученной модели (в литературе его называют слоем "бутылочным горлышком" - "bottleneck layer"), туда мы поместим наши собственные полносвязные слои, которые в предыдущем блоки шли за полной предуобченной моделью. Признаки, содержащиеся в "бутылочном горлышке", представляют наибольшую ценность, так как именно они содержат самые  общие признаки изображений (в отличие от более специфичных признаков для конкретных классов в верхних слоях).

# %%
do_fine_tuning = False
feature_extractor_bottleneck = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
feature_extractor_bottleneck.trainable = do_fine_tuning

# %% [markdown]
# ## <b>Модель 2.1</b> | Bottleneck baseline

# %% [markdown]
# ### Архитектура модели

# %% [markdown]
# Добавим слой `Flatten`, который мы исключаем из предобученной модели, чтобы перевести матрицы изображений в векторный вид (либо можно активировать аттрибут `pooling` внутри самого `feature_extractor`), другие слои пока добавлять не будем.

# %%
print(f'Строим модель на базе {MODULE_HANDLE}.')
print(f'Разморозка слоев: {do_fine_tuning}.\n')

strides = 2

model = tf.keras.Sequential([

            rescale,
            data_aug,

            feature_extractor_bottleneck,

            tf.keras.layers.Conv2D(32, (3, 3), padding="same",
                               strides=2, activation='relu'),
            tf.keras.layers.MaxPooling2D((2, 2)),
            tf.keras.layers.Conv2D(64, (3, 3), padding="same",
                               strides=strides, activation='relu'),

            tf.keras.layers.Flatten(),

            tf.keras.layers.Dropout(DROPOUT_RATE),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(64, activation='relu',
                                  kernel_regularizer=REGULARIZER,
                                  bias_regularizer=REGULARIZER),

            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(num_classes, activation='softmax',
                                  kernel_regularizer=REGULARIZER,
                                  bias_regularizer=REGULARIZER)

], name='bottleneck_baseline')

model.summary()
# Out:
# Строим модель на базе tf.keras.applications.MobileNetV2.
# Разморозка слоев: False.
#
# Model: "bottleneck_baseline"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  sequential_1 (Sequential)   (None, 224, 224, 3)       0
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  conv2d_95 (Conv2D)          (None, 4, 4, 32)          368672
#
#  max_pooling2d_71 (MaxPoolin  (None, 2, 2, 32)         0
#  g2D)
#
#  conv2d_96 (Conv2D)          (None, 1, 1, 64)          18496
#
#  flatten_27 (Flatten)        (None, 64)                0
#
#  dropout_34 (Dropout)        (None, 64)                0
#
#  batch_normalization_58 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_66 (Dense)            (None, 64)                4160
#
#  batch_normalization_59 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_67 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 2,650,149
# Trainable params: 391,909
# Non-trainable params: 2,258,240
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 12

# %% [markdown]
# ### Компиляция

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=BASE_LR),
              loss='categorical_crossentropy',
              metrics=metrics)

# %% [markdown]
# ### Обучение модели

# %%
hist = model.fit(train_batches,
                 epochs=EPOCHS,
                 validation_data=validation_batches,
                 callbacks=[early_stopping, lr_schedule])
# Out:
# Epoch 1/500
# 34/34 [==============================] - 76s 2s/step - loss: 7.4646 - accuracy: 0.2741 - PR_AUC: 0.2606 - val_loss: 7.1673 - val_accuracy: 0.2956 - val_PR_AUC: 0.3058 - lr: 0.0100
# Epoch 2/500
# 34/34 [==============================] - 74s 2s/step - loss: 6.8861 - accuracy: 0.3352 - PR_AUC: 0.3418 - val_loss: 6.8597 - val_accuracy: 0.3019 - val_PR_AUC: 0.3263 - lr: 0.0100
# Epoch 3/500
# 34/34 [==============================] - 58s 2s/step - loss: 6.5697 - accuracy: 0.3824 - PR_AUC: 0.3715 - val_loss: 6.4049 - val_accuracy: 0.3711 - val_PR_AUC: 0.3284 - lr: 0.0100
# Epoch 4/500
# 34/34 [==============================] - 60s 2s/step - loss: 6.1660 - accuracy: 0.4463 - PR_AUC: 0.4704 - val_loss: 6.1635 - val_accuracy: 0.4151 - val_PR_AUC: 0.4091 - lr: 0.0100
# Epoch 5/500
# 34/34 [==============================] - 57s 2s/step - loss: 5.9048 - accuracy: 0.4833 - PR_AUC: 0.5098 - val_loss: 5.9729 - val_accuracy: 0.3962 - val_PR_AUC: 0.3864 - lr: 0.0100
# Epoch 6/500
# 34/34 [==============================] - 68s 2s/step - loss: 5.7128 - accuracy: 0.4685 - PR_AUC: 0.4957 - val_loss: 5.8013 - val_accuracy: 0.3396 - val_PR_AUC: 0.3880 - lr: 0.0100
# Epoch 7/500
# 34/34 [==============================] - 65s 2s/step - loss: 5.4244 - accuracy: 0.5426 - PR_AUC: 0.5583 - val_loss: 5.6614 - val_accuracy: 0.3836 - val_PR_AUC: 0.3729 - lr: 0.0100
# Epoch 8/500
# 34/34 [==============================] - 69s 2s/step - loss: 5.1886 - accuracy: 0.5537 - PR_AUC: 0.5938 - val_loss: 5.4625 - val_accuracy: 0.4403 - val_PR_AUC: 0.4409 - lr: 0.0100
# Epoch 9/500
# 34/34 [==============================] - 67s 2s/step - loss: 5.0207 - accuracy: 0.5574 - PR_AUC: 0.5766 - val_loss: 5.4196 - val_accuracy: 0.4151 - val_PR_AUC: 0.4374 - lr: 0.0100
# Epoch 10/500
# 34/34 [==============================] - 65s 2s/step - loss: 4.7904 - accuracy: 0.5731 - PR_AUC: 0.6135 - val_loss: 5.0222 - val_accuracy: 0.4843 - val_PR_AUC: 0.4829 - lr: 0.0100
# Epoch 11/500
# 34/34 [==============================] - 69s 2s/step - loss: 4.6213 - accuracy: 0.5833 - PR_AUC: 0.6103 - val_loss: 4.8096 - val_accuracy: 0.4969 - val_PR_AUC: 0.5125 - lr: 0.0100
# Epoch 12/500
# 34/34 [==============================] - 90s 3s/step - loss: 4.3990 - accuracy: 0.5731 - PR_AUC: 0.6306 - val_loss: 4.5091 - val_accuracy: 0.5031 - val_PR_AUC: 0.5433 - lr: 0.0100
# Epoch 13/500
# 34/34 [==============================] - 76s 2s/step - loss: 4.2232 - accuracy: 0.6019 - PR_AUC: 0.6520 - val_loss: 4.3318 - val_accuracy: 0.4969 - val_PR_AUC: 0.5483 - lr: 0.0100
# Epoch 14/500
# 34/34 [==============================] - 77s 2s/step - loss: 4.0750 - accuracy: 0.5907 - PR_AUC: 0.6311 - val_loss: 4.2882 - val_accuracy: 0.4780 - val_PR_AUC: 0.4704 - lr: 0.0100
# Epoch 15/500
# 34/34 [==============================] - 87s 3s/step - loss: 3.8792 - accuracy: 0.6065 - PR_AUC: 0.6612 - val_loss: 4.0406 - val_accuracy: 0.4843 - val_PR_AUC: 0.5259 - lr: 0.0100
# Epoch 16/500
# 34/34 [==============================] - 67s 2s/step - loss: 3.7125 - accuracy: 0.6241 - PR_AUC: 0.6661 - val_loss: 3.8190 - val_accuracy: 0.5472 - val_PR_AUC: 0.5785 - lr: 0.0100
# Epoch 17/500
# 34/34 [==============================] - 72s 2s/step - loss: 3.5042 - accuracy: 0.6324 - PR_AUC: 0.7073 - val_loss: 3.6809 - val_accuracy: 0.5409 - val_PR_AUC: 0.5857 - lr: 0.0100
# Epoch 18/500
# 34/34 [==============================] - 63s 2s/step - loss: 3.4091 - accuracy: 0.6343 - PR_AUC: 0.6849 - val_loss: 3.5219 - val_accuracy: 0.5472 - val_PR_AUC: 0.5861 - lr: 0.0100
# Epoch 19/500
# 34/34 [==============================] - 62s 2s/step - loss: 3.2384 - accuracy: 0.6444 - PR_AUC: 0.7050 - val_loss: 3.4422 - val_accuracy: 0.5157 - val_PR_AUC: 0.5674 - lr: 0.0100
# Epoch 20/500
# 34/34 [==============================] - 71s 2s/step - loss: 3.0867 - accuracy: 0.6463 - PR_AUC: 0.7252 - val_loss: 3.2737 - val_accuracy: 0.5283 - val_PR_AUC: 0.5836 - lr: 0.0100
# Epoch 21/500
# 34/34 [==============================] - 64s 2s/step - loss: 2.9629 - accuracy: 0.6556 - PR_AUC: 0.6980 - val_loss: 3.1797 - val_accuracy: 0.5157 - val_PR_AUC: 0.5675 - lr: 0.0100
# Epoch 22/500
# 34/34 [==============================] - 66s 2s/step - loss: 2.8392 - accuracy: 0.6463 - PR_AUC: 0.7152 - val_loss: 3.0661 - val_accuracy: 0.5660 - val_PR_AUC: 0.5753 - lr: 0.0100
# Epoch 23/500
# 34/34 [==============================] - 67s 2s/step - loss: 2.7424 - accuracy: 0.6370 - PR_AUC: 0.7082 - val_loss: 2.9877 - val_accuracy: 0.5660 - val_PR_AUC: 0.5365 - lr: 0.0100
# Epoch 24/500
# 34/34 [==============================] - 61s 2s/step - loss: 2.5886 - accuracy: 0.6574 - PR_AUC: 0.7222 - val_loss: 2.9242 - val_accuracy: 0.4654 - val_PR_AUC: 0.5182 - lr: 0.0100
# Epoch 25/500
# 34/34 [==============================] - 65s 2s/step - loss: 2.4998 - accuracy: 0.6583 - PR_AUC: 0.7144 - val_loss: 2.8193 - val_accuracy: 0.4906 - val_PR_AUC: 0.5302 - lr: 0.0100
# Epoch 26/500
# 34/34 [==============================] - 62s 2s/step - loss: 2.3582 - accuracy: 0.6574 - PR_AUC: 0.7292 - val_loss: 2.5354 - val_accuracy: 0.5535 - val_PR_AUC: 0.6339 - lr: 0.0100
# Epoch 27/500
# 34/34 [==============================] - 59s 2s/step - loss: 2.2700 - accuracy: 0.6704 - PR_AUC: 0.7372 - val_loss: 2.4670 - val_accuracy: 0.5472 - val_PR_AUC: 0.6128 - lr: 0.0100
# Epoch 28/500
# 34/34 [==============================] - 76s 2s/step - loss: 2.1508 - accuracy: 0.6778 - PR_AUC: 0.7408 - val_loss: 2.3562 - val_accuracy: 0.5660 - val_PR_AUC: 0.6141 - lr: 0.0100
# Epoch 29/500
# 34/34 [==============================] - 70s 2s/step - loss: 2.0489 - accuracy: 0.6685 - PR_AUC: 0.7547 - val_loss: 2.3091 - val_accuracy: 0.5346 - val_PR_AUC: 0.5943 - lr: 0.0100
# Epoch 30/500
# 34/34 [==============================] - 98s 3s/step - loss: 1.9360 - accuracy: 0.6852 - PR_AUC: 0.7647 - val_loss: 2.1879 - val_accuracy: 0.5786 - val_PR_AUC: 0.6312 - lr: 0.0100
# Epoch 31/500
# 34/34 [==============================] - 74s 2s/step - loss: 1.8573 - accuracy: 0.6741 - PR_AUC: 0.7678 - val_loss: 2.1356 - val_accuracy: 0.5849 - val_PR_AUC: 0.6072 - lr: 0.0100
# Epoch 32/500
# 34/34 [==============================] - 77s 2s/step - loss: 1.7838 - accuracy: 0.6824 - PR_AUC: 0.7649 - val_loss: 2.0289 - val_accuracy: 0.5346 - val_PR_AUC: 0.6152 - lr: 0.0100
# Epoch 33/500
# 34/34 [==============================] - 75s 2s/step - loss: 1.7046 - accuracy: 0.6852 - PR_AUC: 0.7662 - val_loss: 1.9255 - val_accuracy: 0.6164 - val_PR_AUC: 0.6327 - lr: 0.0100
# Epoch 34/500
# 34/34 [==============================] - 77s 2s/step - loss: 1.6697 - accuracy: 0.6713 - PR_AUC: 0.7481 - val_loss: 1.8860 - val_accuracy: 0.5849 - val_PR_AUC: 0.6203 - lr: 0.0100
# Epoch 35/500
# 34/34 [==============================] - 74s 2s/step - loss: 1.5968 - accuracy: 0.6713 - PR_AUC: 0.7485 - val_loss: 1.9606 - val_accuracy: 0.5031 - val_PR_AUC: 0.5611 - lr: 0.0100
# Epoch 36/500
# 34/34 [==============================] - 62s 2s/step - loss: 1.5140 - accuracy: 0.7056 - PR_AUC: 0.7715 - val_loss: 1.7543 - val_accuracy: 0.5975 - val_PR_AUC: 0.6493 - lr: 0.0050
# Epoch 37/500
# 34/34 [==============================] - 69s 2s/step - loss: 1.4457 - accuracy: 0.7056 - PR_AUC: 0.7907 - val_loss: 1.7294 - val_accuracy: 0.5660 - val_PR_AUC: 0.6406 - lr: 0.0050
# Epoch 38/500
# 34/34 [==============================] - 75s 2s/step - loss: 1.4446 - accuracy: 0.6889 - PR_AUC: 0.7709 - val_loss: 1.7063 - val_accuracy: 0.5975 - val_PR_AUC: 0.6476 - lr: 0.0050
# Epoch 39/500
# 34/34 [==============================] - 72s 2s/step - loss: 1.3769 - accuracy: 0.7083 - PR_AUC: 0.7986 - val_loss: 1.6533 - val_accuracy: 0.5912 - val_PR_AUC: 0.6644 - lr: 0.0050
# Epoch 40/500
# 34/34 [==============================] - 71s 2s/step - loss: 1.3517 - accuracy: 0.7213 - PR_AUC: 0.7867 - val_loss: 1.6493 - val_accuracy: 0.5912 - val_PR_AUC: 0.6537 - lr: 0.0050
# Epoch 41/500
# 34/34 [==============================] - 70s 2s/step - loss: 1.3457 - accuracy: 0.7009 - PR_AUC: 0.7893 - val_loss: 1.6811 - val_accuracy: 0.6038 - val_PR_AUC: 0.6333 - lr: 0.0050
# Epoch 42/500
# 34/34 [==============================] - 73s 2s/step - loss: 1.3032 - accuracy: 0.7204 - PR_AUC: 0.8022 - val_loss: 1.6091 - val_accuracy: 0.6101 - val_PR_AUC: 0.6536 - lr: 0.0025
# Epoch 43/500
# 34/34 [==============================] - 67s 2s/step - loss: 1.2904 - accuracy: 0.7102 - PR_AUC: 0.7967 - val_loss: 1.5859 - val_accuracy: 0.6101 - val_PR_AUC: 0.6541 - lr: 0.0025
# Epoch 44/500
# 34/34 [==============================] - 59s 2s/step - loss: 1.3263 - accuracy: 0.7019 - PR_AUC: 0.7781 - val_loss: 1.5506 - val_accuracy: 0.5912 - val_PR_AUC: 0.6735 - lr: 0.0025
# Epoch 45/500
# 34/34 [==============================] - 60s 2s/step - loss: 1.2551 - accuracy: 0.7120 - PR_AUC: 0.8071 - val_loss: 1.5561 - val_accuracy: 0.5912 - val_PR_AUC: 0.6668 - lr: 0.0025
# Epoch 46/500
# 34/34 [==============================] - 59s 2s/step - loss: 1.2638 - accuracy: 0.7148 - PR_AUC: 0.8015 - val_loss: 1.5445 - val_accuracy: 0.6038 - val_PR_AUC: 0.6714 - lr: 0.0012
# Epoch 47/500
# 34/34 [==============================] - 59s 2s/step - loss: 1.2413 - accuracy: 0.7259 - PR_AUC: 0.8027 - val_loss: 1.5325 - val_accuracy: 0.5849 - val_PR_AUC: 0.6696 - lr: 0.0012
# Epoch 48/500
# 34/34 [==============================] - 60s 2s/step - loss: 1.2542 - accuracy: 0.6972 - PR_AUC: 0.7963 - val_loss: 1.5401 - val_accuracy: 0.6038 - val_PR_AUC: 0.6650 - lr: 0.0012
# Epoch 49/500
# 34/34 [==============================] - 69s 2s/step - loss: 1.2024 - accuracy: 0.7454 - PR_AUC: 0.8196 - val_loss: 1.5262 - val_accuracy: 0.6352 - val_PR_AUC: 0.6712 - lr: 6.2500e-04
# Epoch 50/500
# 34/34 [==============================] - 56s 2s/step - loss: 1.1939 - accuracy: 0.7361 - PR_AUC: 0.8205 - val_loss: 1.5228 - val_accuracy: 0.6289 - val_PR_AUC: 0.6724 - lr: 6.2500e-04
# Epoch 51/500
# 34/34 [==============================] - 65s 2s/step - loss: 1.2019 - accuracy: 0.7509 - PR_AUC: 0.8241 - val_loss: 1.5197 - val_accuracy: 0.6164 - val_PR_AUC: 0.6736 - lr: 6.2500e-04
# Epoch 52/500
# 34/34 [==============================] - 55s 2s/step - loss: 1.2214 - accuracy: 0.7185 - PR_AUC: 0.8075 - val_loss: 1.5130 - val_accuracy: 0.6038 - val_PR_AUC: 0.6737 - lr: 6.2500e-04
# Epoch 53/500
# 34/34 [==============================] - 62s 2s/step - loss: 1.2008 - accuracy: 0.7343 - PR_AUC: 0.8144 - val_loss: 1.5117 - val_accuracy: 0.6164 - val_PR_AUC: 0.6730 - lr: 6.2500e-04
# Epoch 54/500
# 34/34 [==============================] - 62s 2s/step - loss: 1.2148 - accuracy: 0.7157 - PR_AUC: 0.8053 - val_loss: 1.5205 - val_accuracy: 0.6038 - val_PR_AUC: 0.6715 - lr: 6.2500e-04
# Epoch 55/500
# 34/34 [==============================] - 75s 2s/step - loss: 1.2071 - accuracy: 0.7213 - PR_AUC: 0.8082 - val_loss: 1.5156 - val_accuracy: 0.6101 - val_PR_AUC: 0.6729 - lr: 3.1250e-04
# Epoch 56/500
# 34/34 [==============================] - 71s 2s/step - loss: 1.2016 - accuracy: 0.7222 - PR_AUC: 0.8123 - val_loss: 1.5147 - val_accuracy: 0.6164 - val_PR_AUC: 0.6729 - lr: 1.5625e-04
# Epoch 57/500
# 34/34 [==============================] - 76s 2s/step - loss: 1.2026 - accuracy: 0.7389 - PR_AUC: 0.8099 - val_loss: 1.5171 - val_accuracy: 0.6038 - val_PR_AUC: 0.6722 - lr: 7.8125e-05
# Epoch 58/500
# 34/34 [==============================] - 68s 2s/step - loss: 1.2291 - accuracy: 0.7102 - PR_AUC: 0.7957 - val_loss: 1.5167 - val_accuracy: 0.6038 - val_PR_AUC: 0.6719 - lr: 3.9062e-05
# Epoch 59/500
# 34/34 [==============================] - 69s 2s/step - loss: 1.1952 - accuracy: 0.7222 - PR_AUC: 0.8238 - val_loss: 1.5176 - val_accuracy: 0.6101 - val_PR_AUC: 0.6714 - lr: 1.9531e-05
# Epoch 60/500
# 34/34 [==============================] - 78s 2s/step - loss: 1.2019 - accuracy: 0.7222 - PR_AUC: 0.8097 - val_loss: 1.5175 - val_accuracy: 0.6101 - val_PR_AUC: 0.6712 - lr: 9.7656e-06
# Epoch 61/500
# 34/34 [==============================] - 78s 2s/step - loss: 1.2080 - accuracy: 0.7130 - PR_AUC: 0.8067 - val_loss: 1.5163 - val_accuracy: 0.6101 - val_PR_AUC: 0.6714 - lr: 4.8828e-06
# Epoch 62/500
# 34/34 [==============================] - 81s 2s/step - loss: 1.2152 - accuracy: 0.7287 - PR_AUC: 0.7999 - val_loss: 1.5170 - val_accuracy: 0.6101 - val_PR_AUC: 0.6713 - lr: 2.4414e-06
# Epoch 63/500
# 34/34 [==============================] - 83s 2s/step - loss: 1.2112 - accuracy: 0.7139 - PR_AUC: 0.8083 - val_loss: 1.5177 - val_accuracy: 0.6101 - val_PR_AUC: 0.6708 - lr: 1.2207e-06
# Epoch 64/500
# 34/34 [==============================] - 71s 2s/step - loss: 1.2181 - accuracy: 0.7250 - PR_AUC: 0.8079 - val_loss: 1.5174 - val_accuracy: 0.6101 - val_PR_AUC: 0.6708 - lr: 6.1035e-07
# Epoch 65/500
# 34/34 [==============================] - 73s 2s/step - loss: 1.2248 - accuracy: 0.7139 - PR_AUC: 0.8081 - val_loss: 1.5177 - val_accuracy: 0.6101 - val_PR_AUC: 0.6706 - lr: 3.0518e-07
# Epoch 66/500
# 34/34 [==============================] - 70s 2s/step - loss: 1.2175 - accuracy: 0.7093 - PR_AUC: 0.8008 - val_loss: 1.5184 - val_accuracy: 0.6164 - val_PR_AUC: 0.6703 - lr: 1.5259e-07
# Epoch 67/500
# 34/34 [==============================] - 65s 2s/step - loss: 1.2146 - accuracy: 0.7213 - PR_AUC: 0.8017 - val_loss: 1.5189 - val_accuracy: 0.6164 - val_PR_AUC: 0.6709 - lr: 7.6294e-08
# Epoch 68/500
# 34/34 [==============================] - 64s 2s/step - loss: 1.2023 - accuracy: 0.7361 - PR_AUC: 0.8099 - val_loss: 1.5184 - val_accuracy: 0.6164 - val_PR_AUC: 0.6705 - lr: 3.8147e-08
# Epoch 69/500
# 34/34 [==============================] - 63s 2s/step - loss: 1.1864 - accuracy: 0.7241 - PR_AUC: 0.8248 - val_loss: 1.5192 - val_accuracy: 0.6164 - val_PR_AUC: 0.6698 - lr: 1.9073e-08
# Epoch 70/500
# 34/34 [==============================] - 68s 2s/step - loss: 1.2302 - accuracy: 0.7204 - PR_AUC: 0.7971 - val_loss: 1.5191 - val_accuracy: 0.6101 - val_PR_AUC: 0.6698 - lr: 9.5367e-09
# Epoch 71/500
# 34/34 [==============================] - 66s 2s/step - loss: 1.2237 - accuracy: 0.7157 - PR_AUC: 0.7980 - val_loss: 1.5184 - val_accuracy: 0.6164 - val_PR_AUC: 0.6709 - lr: 4.7684e-09
# Epoch 72/500
# 34/34 [==============================] - 69s 2s/step - loss: 1.1795 - accuracy: 0.7398 - PR_AUC: 0.8227 - val_loss: 1.5175 - val_accuracy: 0.6164 - val_PR_AUC: 0.6718 - lr: 2.3842e-09
# Epoch 73/500
# 34/34 [==============================] - 68s 2s/step - loss: 1.1848 - accuracy: 0.7343 - PR_AUC: 0.8192 - val_loss: 1.5166 - val_accuracy: 0.6164 - val_PR_AUC: 0.6718 - lr: 1.1921e-09

# %% [markdown]
# ### Визуализация данных по работе алгоритма

# %%
val_acc_viz(hist, len(hist.history['accuracy']))

# %% [markdown]
# ### Предсказание модели

# %%
show_predictions(model)
# Out:
# joyfulness is joyfulness (57.78%)
# neutral is neutral (51.43%)
# anger is joyfulness (25.68%)
# neutral is neutral (51.19%)
# neutral is neutral (51.59%)
# fear is neutral (52.27%)
# neutral is neutral (51.88%)
# anger is disgust (23.27%)
# neutral is neutral (50.40%)
# disgust is neutral (52.23%)

# %% [markdown]
# ### Матрица ошибок

# %%
confusion_matrix(model)

# %% [markdown]
# ### Вывод

# %% [markdown]
# Модель очень быстро переобучилась, практически с первых эпох, при этом и ее предсказательная способность значительно выросла. Анализ матрицы ошибок показывает, что лучше всего модель предсказывает класс `neutral`, что неудивительно, так как именно в данном классе у нас больше всего изображений. Зафиксируем лучший показатель `val_accuracy` и сохраним данные по результатам работы модели в отдельные переменные на случай, если потребуется к ним снова обратиться.

# %%
val_acc_best = np.max(hist.history['val_accuracy'])
val_auc_best = np.max(hist.history['val_PR_AUC'])
model_21_best_result = round(val_acc_best, 2), round(val_auc_best, 2)

print(f'val_accuracy: {model_21_best_result[0]}')
print(f'val_PR_AUC: {model_21_best_result[1]}')
# Out:
# val_accuracy: 0.64
# val_PR_AUC: 0.67

# %%
# сохраним данные о модели
model_21 = model
hist_21 = hist

# %% [markdown]
# ## <b>Модель 2.2</b> | Bottleneck baseline cont

# %% [markdown]
# ### Архитектура модели

# %% [markdown]
# Добавим слой `Flatten`, который мы исключаем из предобученной модели, чтобы перевести матрицы изображений в векторный вид (либо можно активировать аттрибут `pooling` внутри самого `feature_extractor`), другие слои пока добавлять не будем.

# %%
print(f'Строим модель на базе {MODULE_HANDLE}.')
print(f'Разморозка слоев: {do_fine_tuning}.\n')

strides = 1

model = tf.keras.Sequential([

            rescale,
            data_aug,

            feature_extractor_bottleneck,

            tf.keras.layers.Conv2D(64, (3, 3), padding="same",
                               strides=2, activation='relu'),
            tf.keras.layers.MaxPooling2D((2, 2)),
            tf.keras.layers.Conv2D(64, (3, 3), padding="same",
                               strides=strides, activation='relu'),

            tf.keras.layers.Flatten(),

            # tf.keras.layers.Dropout(DROPOUT_RATE),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(64, activation='relu',
                                  kernel_regularizer=REGULARIZER,
                                  # bias_regularizer=REGULARIZER
                                 ),

            # tf.keras.layers.Dropout(DROPOUT_RATE),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(64, activation='relu',
                                  kernel_regularizer=REGULARIZER,
                                  # bias_regularizer=REGULARIZER
                                 ),

            # tf.keras.layers.Dropout(DROPOUT_RATE),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(64, activation='relu',
                                  kernel_regularizer=REGULARIZER,
                                  # bias_regularizer=REGULARIZER
                                 ),

            tf.keras.layers.Dropout(DROPOUT_RATE),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(num_classes, activation='softmax',
                                  kernel_regularizer=REGULARIZER,
                                  # bias_regularizer=REGULARIZER
                                 )

], name='bottleneck_baseline_cont')

model.summary()
# Out:
# Строим модель на базе tf.keras.applications.MobileNetV2.
# Разморозка слоев: False.
#
# Model: "bottleneck_baseline_cont"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  sequential_1 (Sequential)   (None, 224, 224, 3)       0
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  conv2d_136 (Conv2D)         (None, 4, 4, 32)          368672
#
#  max_pooling2d_91 (MaxPoolin  (None, 2, 2, 32)         0
#  g2D)
#
#  conv2d_137 (Conv2D)         (None, 2, 2, 64)          18496
#
#  flatten_52 (Flatten)        (None, 256)               0
#
#  batch_normalization_90 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dense_100 (Dense)           (None, 64)                16448
#
#  batch_normalization_91 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_101 (Dense)           (None, 64)                4160
#
#  batch_normalization_92 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_102 (Dense)           (None, 64)                4160
#
#  dropout_53 (Dropout)        (None, 64)                0
#
#  batch_normalization_93 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_103 (Dense)           (None, 5)                 325
#
# =================================================================
# Total params: 2,672,037
# Trainable params: 413,157
# Non-trainable params: 2,258,880
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 20

# %% [markdown]
# ### Компиляция

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=BASE_LR),
              loss='categorical_crossentropy',
              metrics=metrics)

# %% [markdown]
# ### Обучение модели

# %%
hist = model.fit(train_batches,
                 epochs=EPOCHS,
                 validation_data=validation_batches,
                 callbacks=[early_stopping, lr_schedule])
# Out:
# Epoch 1/500
# 34/34 [==============================] - 71s 2s/step - loss: 24.5112 - accuracy: 0.2333 - PR_AUC: 0.2259 - val_loss: 24.0953 - val_accuracy: 0.2642 - val_PR_AUC: 0.2258 - lr: 0.0100
# Epoch 2/500
# 34/34 [==============================] - 72s 2s/step - loss: 23.1053 - accuracy: 0.3306 - PR_AUC: 0.2992 - val_loss: 23.0195 - val_accuracy: 0.3333 - val_PR_AUC: 0.2883 - lr: 0.0100
# Epoch 3/500
# 34/34 [==============================] - 65s 2s/step - loss: 21.8812 - accuracy: 0.3602 - PR_AUC: 0.3500 - val_loss: 21.3945 - val_accuracy: 0.3019 - val_PR_AUC: 0.2826 - lr: 0.0100
# Epoch 4/500
# 34/34 [==============================] - 72s 2s/step - loss: 20.7400 - accuracy: 0.4009 - PR_AUC: 0.3878 - val_loss: 20.1726 - val_accuracy: 0.4340 - val_PR_AUC: 0.3979 - lr: 0.0100
# Epoch 5/500
# 34/34 [==============================] - 76s 2s/step - loss: 19.6573 - accuracy: 0.4269 - PR_AUC: 0.4230 - val_loss: 19.2019 - val_accuracy: 0.3648 - val_PR_AUC: 0.3995 - lr: 0.0100
# Epoch 6/500
# 34/34 [==============================] - 63s 2s/step - loss: 18.5881 - accuracy: 0.4417 - PR_AUC: 0.4640 - val_loss: 18.1822 - val_accuracy: 0.3648 - val_PR_AUC: 0.4254 - lr: 0.0100
# Epoch 7/500
# 34/34 [==============================] - 67s 2s/step - loss: 17.5915 - accuracy: 0.4639 - PR_AUC: 0.4889 - val_loss: 17.1459 - val_accuracy: 0.4591 - val_PR_AUC: 0.5001 - lr: 0.0100
# Epoch 8/500
# 34/34 [==============================] - 67s 2s/step - loss: 16.6065 - accuracy: 0.5111 - PR_AUC: 0.5216 - val_loss: 16.2808 - val_accuracy: 0.4717 - val_PR_AUC: 0.4682 - lr: 0.0100
# Epoch 9/500
# 34/34 [==============================] - 62s 2s/step - loss: 15.6652 - accuracy: 0.5407 - PR_AUC: 0.5681 - val_loss: 15.3511 - val_accuracy: 0.4277 - val_PR_AUC: 0.4665 - lr: 0.0100
# Epoch 10/500
# 34/34 [==============================] - 65s 2s/step - loss: 14.7941 - accuracy: 0.5231 - PR_AUC: 0.5657 - val_loss: 14.4785 - val_accuracy: 0.4214 - val_PR_AUC: 0.4762 - lr: 0.0100
# Epoch 11/500
# 34/34 [==============================] - 53s 2s/step - loss: 13.9372 - accuracy: 0.5352 - PR_AUC: 0.5808 - val_loss: 13.6107 - val_accuracy: 0.4654 - val_PR_AUC: 0.5215 - lr: 0.0100
# Epoch 12/500
# 34/34 [==============================] - 77s 2s/step - loss: 13.0967 - accuracy: 0.5713 - PR_AUC: 0.6022 - val_loss: 12.8296 - val_accuracy: 0.4843 - val_PR_AUC: 0.5553 - lr: 0.0100
# Epoch 13/500
# 34/34 [==============================] - 62s 2s/step - loss: 12.3301 - accuracy: 0.5593 - PR_AUC: 0.5973 - val_loss: 12.0508 - val_accuracy: 0.5031 - val_PR_AUC: 0.5583 - lr: 0.0100
# Epoch 14/500
# 34/34 [==============================] - 71s 2s/step - loss: 11.5642 - accuracy: 0.5750 - PR_AUC: 0.6284 - val_loss: 11.3273 - val_accuracy: 0.5031 - val_PR_AUC: 0.5635 - lr: 0.0100
# Epoch 15/500
# 34/34 [==============================] - 67s 2s/step - loss: 10.8224 - accuracy: 0.5861 - PR_AUC: 0.6376 - val_loss: 10.6442 - val_accuracy: 0.4843 - val_PR_AUC: 0.5499 - lr: 0.0100
# Epoch 16/500
# 34/34 [==============================] - 66s 2s/step - loss: 10.1209 - accuracy: 0.5880 - PR_AUC: 0.6515 - val_loss: 9.9390 - val_accuracy: 0.5094 - val_PR_AUC: 0.5727 - lr: 0.0100
# Epoch 17/500
# 34/34 [==============================] - 70s 2s/step - loss: 9.4340 - accuracy: 0.6046 - PR_AUC: 0.6690 - val_loss: 9.2962 - val_accuracy: 0.4843 - val_PR_AUC: 0.5716 - lr: 0.0100
# Epoch 18/500
# 34/34 [==============================] - 54s 2s/step - loss: 8.8250 - accuracy: 0.6139 - PR_AUC: 0.6578 - val_loss: 8.7051 - val_accuracy: 0.5094 - val_PR_AUC: 0.5506 - lr: 0.0100
# Epoch 19/500
# 34/34 [==============================] - 61s 2s/step - loss: 8.2208 - accuracy: 0.6065 - PR_AUC: 0.6636 - val_loss: 8.1378 - val_accuracy: 0.4780 - val_PR_AUC: 0.5544 - lr: 0.0100
# Epoch 20/500
# 34/34 [==============================] - 54s 2s/step - loss: 7.6631 - accuracy: 0.6056 - PR_AUC: 0.6623 - val_loss: 7.5998 - val_accuracy: 0.4906 - val_PR_AUC: 0.5187 - lr: 0.0100
# Epoch 21/500
# 34/34 [==============================] - 55s 2s/step - loss: 7.0789 - accuracy: 0.6250 - PR_AUC: 0.6961 - val_loss: 7.0134 - val_accuracy: 0.4906 - val_PR_AUC: 0.5970 - lr: 0.0100
# Epoch 22/500
# 34/34 [==============================] - 61s 2s/step - loss: 6.5789 - accuracy: 0.6250 - PR_AUC: 0.6982 - val_loss: 6.5476 - val_accuracy: 0.5220 - val_PR_AUC: 0.5637 - lr: 0.0100
# Epoch 23/500
# 34/34 [==============================] - 63s 2s/step - loss: 6.0831 - accuracy: 0.6194 - PR_AUC: 0.6958 - val_loss: 6.0754 - val_accuracy: 0.5409 - val_PR_AUC: 0.5936 - lr: 0.0100
# Epoch 24/500
# 34/34 [==============================] - 66s 2s/step - loss: 5.6528 - accuracy: 0.6241 - PR_AUC: 0.6945 - val_loss: 5.6472 - val_accuracy: 0.5535 - val_PR_AUC: 0.6026 - lr: 0.0100
# Epoch 25/500
# 34/34 [==============================] - 68s 2s/step - loss: 5.2062 - accuracy: 0.6620 - PR_AUC: 0.7095 - val_loss: 5.2570 - val_accuracy: 0.5346 - val_PR_AUC: 0.5689 - lr: 0.0100
# Epoch 26/500
# 34/34 [==============================] - 62s 2s/step - loss: 4.7970 - accuracy: 0.6593 - PR_AUC: 0.7203 - val_loss: 4.9458 - val_accuracy: 0.5220 - val_PR_AUC: 0.5181 - lr: 0.0100
# Epoch 27/500
# 34/34 [==============================] - 70s 2s/step - loss: 4.4342 - accuracy: 0.6491 - PR_AUC: 0.7155 - val_loss: 4.4807 - val_accuracy: 0.5849 - val_PR_AUC: 0.6253 - lr: 0.0100
# Epoch 28/500
# 34/34 [==============================] - 59s 2s/step - loss: 4.1276 - accuracy: 0.6528 - PR_AUC: 0.7095 - val_loss: 4.2005 - val_accuracy: 0.5786 - val_PR_AUC: 0.5998 - lr: 0.0100
# Epoch 29/500
# 34/34 [==============================] - 69s 2s/step - loss: 3.7884 - accuracy: 0.6574 - PR_AUC: 0.7355 - val_loss: 3.9967 - val_accuracy: 0.4969 - val_PR_AUC: 0.5108 - lr: 0.0100
# Epoch 30/500
# 34/34 [==============================] - 60s 2s/step - loss: 3.5557 - accuracy: 0.6620 - PR_AUC: 0.7091 - val_loss: 3.6911 - val_accuracy: 0.5220 - val_PR_AUC: 0.5537 - lr: 0.0100
# Epoch 31/500
# 34/34 [==============================] - 69s 2s/step - loss: 3.2992 - accuracy: 0.6472 - PR_AUC: 0.7214 - val_loss: 3.5662 - val_accuracy: 0.4780 - val_PR_AUC: 0.4763 - lr: 0.0100
# Epoch 32/500
# 34/34 [==============================] - 63s 2s/step - loss: 3.0930 - accuracy: 0.6463 - PR_AUC: 0.7086 - val_loss: 3.2151 - val_accuracy: 0.5472 - val_PR_AUC: 0.6042 - lr: 0.0100
# Epoch 33/500
# 34/34 [==============================] - 65s 2s/step - loss: 2.8486 - accuracy: 0.6630 - PR_AUC: 0.7276 - val_loss: 3.0565 - val_accuracy: 0.5472 - val_PR_AUC: 0.5719 - lr: 0.0100
# Epoch 34/500
# 34/34 [==============================] - 65s 2s/step - loss: 2.6687 - accuracy: 0.6694 - PR_AUC: 0.7356 - val_loss: 2.8290 - val_accuracy: 0.5472 - val_PR_AUC: 0.6221 - lr: 0.0100
# Epoch 35/500
# 34/34 [==============================] - 64s 2s/step - loss: 2.5601 - accuracy: 0.6398 - PR_AUC: 0.7065 - val_loss: 2.7691 - val_accuracy: 0.5031 - val_PR_AUC: 0.5837 - lr: 0.0100
# Epoch 36/500
# 34/34 [==============================] - 66s 2s/step - loss: 2.3759 - accuracy: 0.6694 - PR_AUC: 0.7300 - val_loss: 2.6060 - val_accuracy: 0.5409 - val_PR_AUC: 0.6014 - lr: 0.0100
# Epoch 37/500
# 34/34 [==============================] - 61s 2s/step - loss: 2.2824 - accuracy: 0.6481 - PR_AUC: 0.7125 - val_loss: 2.4774 - val_accuracy: 0.5723 - val_PR_AUC: 0.5985 - lr: 0.0100
# Epoch 38/500
# 34/34 [==============================] - 67s 2s/step - loss: 2.1466 - accuracy: 0.6556 - PR_AUC: 0.7216 - val_loss: 2.2863 - val_accuracy: 0.5786 - val_PR_AUC: 0.6434 - lr: 0.0100
# Epoch 39/500
# 34/34 [==============================] - 60s 2s/step - loss: 2.0300 - accuracy: 0.6620 - PR_AUC: 0.7305 - val_loss: 2.2409 - val_accuracy: 0.5472 - val_PR_AUC: 0.5993 - lr: 0.0100
# Epoch 40/500
# 34/34 [==============================] - 68s 2s/step - loss: 1.9445 - accuracy: 0.6630 - PR_AUC: 0.7118 - val_loss: 2.1293 - val_accuracy: 0.5660 - val_PR_AUC: 0.5856 - lr: 0.0100
# Epoch 41/500
#  2/34 [>.............................] - ETA: 50s - loss: 1.8873 - accuracy: 0.6406 - PR_AUC: 0.7371
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[341], line 1
# ----> 1 hist = model.fit(train_batches,
#       2                  epochs=EPOCHS,
#       3                  validation_data=validation_batches,
#       4                  callbacks=[early_stopping, lr_schedule])
#
# File C:\Python\venv\venv38\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\Python\venv\venv38\lib\site-packages\keras\engine\training.py:1384, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1377 with tf.profiler.experimental.Trace(
#    1378     'train',
#    1379     epoch_num=epoch,
#    1380     step_num=step,
#    1381     batch_size=batch_size,
#    1382     _r=1):
#    1383   callbacks.on_train_batch_begin(step)
# -> 1384   tmp_logs = self.train_function(iterator)
#    1385   if data_handler.should_sync:
#    1386     context.async_wait()
#
# File C:\Python\venv\venv38\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\Python\venv\venv38\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File C:\Python\venv\venv38\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File C:\Python\venv\venv38\lib\site-packages\tensorflow\python\eager\function.py:2956, in Function.__call__(self, *args, **kwargs)
#    2953 with self._lock:
#    2954   (graph_function,
#    2955    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956 return graph_function._call_flat(
#    2957     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File C:\Python\venv\venv38\lib\site-packages\tensorflow\python\eager\function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1849 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1850 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1851     and executing_eagerly):
#    1852   # No tape is watching; skip to running the function.
# -> 1853   return self._build_call_outputs(self._inference_function.call(
#    1854       ctx, args, cancellation_manager=cancellation_manager))
#    1855 forward_backward = self._select_forward_and_backward_functions(
#    1856     args,
#    1857     possible_gradient_type,
#    1858     executing_eagerly)
#    1859 forward_function, args_with_tangents = forward_backward.forward()
#
# File C:\Python\venv\venv38\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File C:\Python\venv\venv38\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Визуализация данных по работе алгоритма

# %%
val_acc_viz(hist, len(hist.history['accuracy']))

# %% [markdown]
# ### Предсказание модели

# %%
show_predictions(model)
# Out:
# joyfulness is joyfulness (57.78%)
# neutral is neutral (51.43%)
# anger is joyfulness (25.68%)
# neutral is neutral (51.19%)
# neutral is neutral (51.59%)
# fear is neutral (52.27%)
# neutral is neutral (51.88%)
# anger is disgust (23.27%)
# neutral is neutral (50.40%)
# disgust is neutral (52.23%)

# %% [markdown]
# ### Матрица ошибок

# %%
confusion_matrix(model)

# %% [markdown]
# ### Вывод

# %% [markdown]
# Модель очень быстро переобучилась, практически с первых эпох, при этом и ее предсказательная способность значительно выросла. Анализ матрицы ошибок показывает, что лучше всего модель предсказывает класс `neutral`, что неудивительно, так как именно в данном классе у нас больше всего изображений. Зафиксируем лучший показатель `val_accuracy` и сохраним данные по результатам работы модели в отдельные переменные на случай, если потребуется к ним снова обратиться.

# %%
val_acc_best = np.max(hist.history['val_accuracy'])
val_auc_best = np.max(hist.history['val_PR_AUC'])
model_21_best_result = round(val_acc_best, 2), round(val_auc_best, 2)

print(f'val_accuracy: {model_21_best_result[0]}')
print(f'val_PR_AUC: {model_21_best_result[1]}')
# Out:
# val_accuracy: 0.64
# val_PR_AUC: 0.67

# %%
# сохраним данные о модели
model_21 = model
hist_21 = hist

# %% [markdown]
# ## <b>Модель 2.2</b> | `fine_tuning`

# %% [markdown]
# На следующем шаге проверим эту же модель, но разморозим часть слоев предобученной модели. В официальных документах указано, что размораживать слои следует только после того, как мы уже обучили собственный классификатор, в ином случае предобученная модель с установленными в случайном порядке весами для новых слоев при обновлении весов потеряет все, чему она была обучена.
#
# Кроме того, нет необходимости в разморозке "нижних слоев", так как они обнаруживают самые простые и общие закономерности, характерные для любых изображений. Цель применения предобученной модели - использовать более "специализированные" слои для дообучения новой модели на новом датасете, поэтому возьмем сравнительно небольшое число "верхних" слоев.
#
# Особого внимания в случае разморозки `feature_extractor` заслуживают слои bacth normalization (`BN`). Это единственные встроенные слои, веса которых не должны обновляться при градиентном спуске, так как эти веса - движущиеся среднее значение и стандартное отклонение для нормализации текущего батча. Запустив модель в режиме `trainable=False`, мы эти слои заморозили. Когда мы на следующем шаге размораживаем всю модель или ее часть, слои BN продолжают работать в режиме inference (движущиеся mean и std), а не обучения (mean и std текущего батча). Это очень важный момент, так как если мы запустим `feature_extractor` сразу в режиме разморозки без предварительного обучения на замороженных слоях (то есть не заморозим веса BN), слои BN будут давать непредсказуемый результат (подробнее о проблеме [здесь](https://keras.io/getting_started/faq/#whats-the-difference-between-the-training-argument-in-call-and-the-trainable-attribute)).

# %% [markdown]
# ## Модуль `tf.keras.applications` | `feature_extractor_layer`

# %%
do_fine_tuning = True
feature_extractor_bottleneck = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
feature_extractor_bottleneck.trainable = do_fine_tuning

print(f'Разморозка слоев: {do_fine_tuning}.')
# Out:
# Разморозка слоев: True.

# %% [markdown]
# Посмотрим на количество слоев в предобученной модели:

# %%
print("Number of layers in the feature extractor: ", len(feature_extractor_bottleneck.layers))
# Out:
# Number of layers in the feature extractor:  154

# %%
# с какого слоя мы размораживаем модель
fine_tune_at = 100

# Заморозим все остальные слои
for layer in feature_extractor_bottleneck.layers[:fine_tune_at]:
    layer.trainable = False

print("Trainable layers in the feature extractor: ", len(feature_extractor_bottleneck.trainable_variables))
# Out:
# Trainable layers in the feature extractor:  54

# %%
print(f'Строим модель на базе {MODULE_HANDLE}.')
print(f'Разморозка слоев: {do_fine_tuning}.\n')

strides = 1

model = tf.keras.Sequential([

            rescale,
            # data_aug,

            feature_extractor_bottleneck,

            tf.keras.layers.Conv2D(32, (3, 3), padding="same",
                               strides=2, activation='relu'),
            tf.keras.layers.MaxPooling2D((2, 2)),
            tf.keras.layers.Conv2D(64, (3, 3), padding="same",
                               strides=strides, activation='relu'),

            tf.keras.layers.Flatten(),

            tf.keras.layers.Dropout(DROPOUT_RATE*2),
            # tf.keras.layers.BatchNormalization(),
            # tf.keras.layers.Dense(64, activation='relu',
            #                       kernel_regularizer=REGULARIZER,
            #                       bias_regularizer=REGULARIZER),

            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(num_classes, activation='softmax',
                                  kernel_regularizer=REGULARIZER,
                                  # bias_regularizer=REGULARIZER
                                 )

], name='bottleneck_baseline_cont')

model.summary()
# Out:
# Строим модель на базе tf.keras.applications.MobileNetV2.
# Разморозка слоев: True.
#
# Model: "bottleneck_baseline_cont"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  conv2d_134 (Conv2D)         (None, 4, 4, 32)          368672
#
#  max_pooling2d_90 (MaxPoolin  (None, 2, 2, 32)         0
#  g2D)
#
#  conv2d_135 (Conv2D)         (None, 2, 2, 64)          18496
#
#  flatten_51 (Flatten)        (None, 256)               0
#
#  dropout_52 (Dropout)        (None, 256)               0
#
#  batch_normalization_89 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dense_99 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 2,647,461
# Trainable params: 2,250,405
# Non-trainable params: 397,056
# _________________________________________________________________

# %% [markdown]
# ## Компиляция

# %% [markdown]
# Теперь необходимо скомпилировать нашу уже обученную на предыдущем этапе модель, чтобы изменения были применены.

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=BASE_LR),
              loss='categorical_crossentropy',
              metrics=metrics)

# %% [markdown]
# ## Архитектура модели

# %%
model.summary()
# Out:
# Model: "bottleneck_baseline_cont"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  conv2d_134 (Conv2D)         (None, 4, 4, 32)          368672
#
#  max_pooling2d_90 (MaxPoolin  (None, 2, 2, 32)         0
#  g2D)
#
#  conv2d_135 (Conv2D)         (None, 2, 2, 64)          18496
#
#  flatten_51 (Flatten)        (None, 256)               0
#
#  dropout_52 (Dropout)        (None, 256)               0
#
#  batch_normalization_89 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dense_99 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 2,647,461
# Trainable params: 2,250,405
# Non-trainable params: 397,056
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 62

# %% [markdown]
# ## Обучение модели

# %%
hist = model.fit(train_batches,
                 epochs=EPOCHS,
                 validation_data=validation_batches,
                 callbacks=[early_stopping, lr_schedule])
# Out:
# Epoch 1/500
# 34/34 [==============================] - 102s 3s/step - loss: 21.6522 - accuracy: 0.2759 - PR_AUC: 0.2661 - val_loss: 8.2551 - val_accuracy: 0.3145 - val_PR_AUC: 0.2779 - lr: 0.0100
# Epoch 2/500
# 34/34 [==============================] - 76s 2s/step - loss: 8.1061 - accuracy: 0.3556 - PR_AUC: 0.3587 - val_loss: 8.2091 - val_accuracy: 0.2704 - val_PR_AUC: 0.2421 - lr: 0.0100
# Epoch 3/500
# 34/34 [==============================] - 96s 3s/step - loss: 8.0931 - accuracy: 0.4259 - PR_AUC: 0.4157 - val_loss: 8.1059 - val_accuracy: 0.3333 - val_PR_AUC: 0.2760 - lr: 0.0100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[334], line 1
# ----> 1 hist = model.fit(train_batches,
#       2                  epochs=EPOCHS,
#       3                  validation_data=validation_batches,
#       4                  callbacks=[early_stopping, lr_schedule])
#
# File C:\Python\venv\venv38\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\Python\venv\venv38\lib\site-packages\keras\engine\training.py:1373, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1371 logs = None
#    1372 for epoch, iterator in data_handler.enumerate_epochs():
# -> 1373   self.reset_metrics()
#    1374   callbacks.on_epoch_begin(epoch)
#    1375   with data_handler.catch_stop_iteration():
#
# KeyboardInterrupt:

# %% [markdown]
# # <b>МОДЕЛЬ 3</b> | `fine_tuning`

# %% [markdown]
# # <b>Модель 3.1</b> | Pretrained baseline

# %% [markdown]
# ## Модуль `tf.keras.applications` | `feature_extractor_layer`

# %% [markdown]
# Попробуем предолеть проблему переобучения, добавив к предыдущей архитектуре слои с аугментацией данных, которые мы подготовили заранее. Другие параметры оставим нетронутыми. Обратим внимание, что мы создаем новую модель, а не дообучаем предыдущую (дообучением мы займемся позже).

# %%
do_fine_tuning = False
feature_extractor = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
feature_extractor.trainable = do_fine_tuning

# %%
do_fine_tuning = False
feature_extractor = tf.keras.applications.MobileNet(
                                                input_shape=IMG_SHAPE,
                                                # alpha=1.0,
                                                # depth_multiplier=1,
                                                dropout=DROPOUT_RATE,
                                                include_top=False,
                                                weights="imagenet",
                                                # input_tensor=None,
                                                # pooling=None,
                                                # classes=1000,
                                                classifier_activation='softmax',
                                                # **kwargs
)
feature_extractor.trainable = do_fine_tuning

# %%
do_fine_tuning = False
feature_extractor = tf.keras.applications.InceptionV3(
                                                include_top=False,
                                                weights="imagenet",
                                                # input_tensor=None,
                                                input_shape=IMG_SHAPE,
                                                # pooling=None,
                                                # classes=1000,
                                                # classifier_activation="softmax",
)
feature_extractor.trainable = do_fine_tuning

# %%
do_fine_tuning = False
feature_extractor = tf.keras.applications.InceptionResNetV2(
                                                include_top=False,
                                                weights="imagenet",
                                                # input_tensor=None,
                                                input_shape=IMG_SHAPE,
                                                # pooling=None,
                                                # classes=1000,
                                                # classifier_activation="softmax",
                                                # **kwargs
)
feature_extractor.trainable = do_fine_tuning

# %%
# feature_extractor.summary()

# %% [markdown]
# ## Архитектура модели

# %%
image_batch, label_batch = next(iter(train_batches))
feature_batch = feature_extractor(image_batch)
print(feature_batch.shape)
# Out:
# (32, 5, 5, 1536)

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (32, 1536)

# %%
prediction_layer = tf.keras.layers.Dense(num_classes, activation='softmax',
                                  kernel_regularizer=REGULARIZER
                                 )
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (32, 5)

# %%
inputs = tf.keras.Input(shape=IMG_SHAPE)
x = rescale(inputs)
x = data_aug(x)
x = feature_extractor(x, training=False)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(DROPOUT_RATE)(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_33 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  sequential_1 (Sequential)   (None, 224, 224, 3)       0
#
#  inception_resnet_v2 (Functi  (None, 5, 5, 1536)       54336736
#  onal)
#
#  global_average_pooling2d_8   (None, 1536)             0
#  (GlobalAveragePooling2D)
#
#  dropout_112 (Dropout)       (None, 1536)              0
#
#  dense_199 (Dense)           (None, 5)                 7685
#
# =================================================================
# Total params: 54,344,421
# Trainable params: 7,685
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %%
# print(f'Строим модель на базе {MODULE_HANDLE}.')
# print(f'Разморозка слоев: {do_fine_tuning}.\n')

# strides = 1
# REGULARIZER=tf.keras.regularizers.L1L2(l1=0.0, l2=0.5)

# model = tf.keras.Sequential([

#             rescale,
#             data_aug,

#             feature_extractor,

#             # tf.keras.layers.Conv2D(32, (3, 3), padding="same",
#             #                    strides=strides, activation='relu'),
#             # tf.keras.layers.MaxPooling2D((2, 2)),
#             # tf.keras.layers.Conv2D(64, (3, 3), padding="same",
#             #                    strides=strides, activation='relu'),

#             tf.keras.layers.Flatten(),
#             tf.keras.layers.Dropout(DROPOUT_RATE),
#             tf.keras.layers.BatchNormalization(),
#             tf.keras.layers.Dense(num_classes, activation='softmax',
#                                   kernel_regularizer=REGULARIZER
#                                  )

# ], name='pretrained_baseline')

# model.summary()

# %%
len(model.trainable_variables)
# Out:
# 2

# %% [markdown]
# ## Компиляция

# %%
model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=BASE_LR),
              loss='mse',
              metrics=metrics)

# %% [markdown]
# ## Обучение модели

# %%
hist = model.fit(train_batches,
                 epochs=1,
                 validation_data=validation_batches,
                 callbacks=[early_stopping, lr_schedule])
# Out:
# 34/34 [==============================] - 596s 17s/step - loss: 0.5878 - accuracy: 0.2065 - PR_AUC: 0.2008 - val_loss: 0.4632 - val_accuracy: 0.1258 - val_PR_AUC: 0.1798 - lr: 0.0100

# %% [markdown]
# ### Визуализация данных по работе алгоритма

# %%
val_acc_viz(hist, len(hist.history['accuracy']))

# %% [markdown]
# ### Предсказание модели

# %%
show_predictions(model, visualization=False)
# Out:
# neutral is joyfulness (25.89%)
# joyfulness is joyfulness (25.84%)
# neutral is joyfulness (30.97%)
# disgust is disgust (34.32%)
# joyfulness is neutral (25.35%)
# disgust is fear (30.97%)
# anger is fear (27.86%)
# neutral is joyfulness (28.11%)
# neutral is joyfulness (30.43%)
# neutral is neutral (26.82%)

# %% [markdown]
# ### Матрица ошибок

# %%
confusion_matrix(model)

# %% [markdown]
# ### Вывод

# %%
val_acc_best = np.max(hist.history['val_accuracy'])
val_auc_best = np.max(hist.history['val_PR_AUC'])
model_best_results = round(val_acc_best, 2), round(val_auc_best, 2)

print(f'val_accuracy: {model_best_results[0]}')
print(f'val_PR_AUC: {model_best_results[1]}')
# Out:
# val_accuracy: 0.31
# val_PR_AUC: 0.29

# %%
# сохраним данные о модели
model_pretrained = model
hist_pretrained = hist

# %%
# stat_3['SGD 1_layer_1024'] = model_best_results[1]

# %%
# stat_3
# Out:
# {'1_layer_1024': 0.27, 'SGD 1_layer_1024': 0.29}

# %% [markdown]
# ## Разморозка слоев

# %%
do_fine_tuning = True
# feature_extractor = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
#                                                include_top=False,
#                                                weights='imagenet')
feature_extractor.trainable = do_fine_tuning

print(f'Разморозка слоев: {do_fine_tuning}.')
# Out:
# Разморозка слоев: True.

# %% [markdown]
# Посмотрим на количество слоев в предобученной модели:

# %%
# с какого слоя мы размораживаем модель
fine_tune_at = 1

# Заморозим все остальные слои
for layer in feature_extractor.layers[:fine_tune_at]:
    layer.trainable = False

# %%
print("Number of layers in the feature extractor: ", len(feature_extractor.layers))
print("Trainable layers in the feature extractor: ", len(feature_extractor.trainable_variables))
# Out:
# Number of layers in the feature extractor:  780
# Trainable layers in the feature extractor:  488

# %% [markdown]
# ## Компиляция

# %% [markdown]
# Теперь необходимо скомпилировать нашу уже обученную на предыдущем этапе модель, чтобы изменения были применены.

# %%
model.compile(optimizer=tf.keras.optimizers.RMSprop(),
              loss='mse',
              metrics=metrics)

# %% [markdown]
# ## Архитектура модели

# %%
model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_33 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  sequential_1 (Sequential)   (None, 224, 224, 3)       0
#
#  inception_resnet_v2 (Functi  (None, 5, 5, 1536)       54336736
#  onal)
#
#  global_average_pooling2d_8   (None, 1536)             0
#  (GlobalAveragePooling2D)
#
#  dropout_112 (Dropout)       (None, 1536)              0
#
#  dense_199 (Dense)           (None, 5)                 7685
#
# =================================================================
# Total params: 54,344,421
# Trainable params: 54,283,877
# Non-trainable params: 60,544
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 490

# %% [markdown]
# ## Обучение

# %%
hist = model.fit(train_batches,
                 epochs=EPOCHS,
                 validation_data=validation_batches,
                 callbacks=[early_stopping, lr_schedule])
# Out:
# Epoch 1/500
#  3/34 [=>............................] - ETA: 49:09 - loss: 0.4828 - accuracy: 0.1250 - PR_AUC: 0.1769
# KeyboardInterrupt

# %% [markdown]
# ### Визуализация данных по работе алгоритма

# %%
val_acc_viz(hist, len(hist.history['accuracy']))

# %% [markdown]
# ### Предсказание модели

# %%
show_predictions(model, visualization=False)
# Out:
# neutral is joyfulness (25.89%)
# joyfulness is joyfulness (25.84%)
# neutral is joyfulness (30.97%)
# disgust is disgust (34.32%)
# joyfulness is neutral (25.35%)
# disgust is fear (30.97%)
# anger is fear (27.86%)
# neutral is joyfulness (28.11%)
# neutral is joyfulness (30.43%)
# neutral is neutral (26.82%)

# %% [markdown]
# ### Матрица ошибок

# %%
confusion_matrix(model)

# %% [markdown]
# ### Вывод

# %%
val_acc_best = np.max(hist.history['val_accuracy'])
val_auc_best = np.max(hist.history['val_PR_AUC'])
model_best_results = round(val_acc_best, 2), round(val_auc_best, 2)

print(f'val_accuracy: {model_best_results[0]}')
print(f'val_PR_AUC: {model_best_results[1]}')
# Out:
# val_accuracy: 0.31
# val_PR_AUC: 0.29

# %%
# сохраним данные о модели
model_32 = model
hist_32 = hist

# %%
stat_3['SGD 1_layer_1024'] = model_best_results[1]

# %%
stat_3
# Out:
# {'1_layer_1024': 0.27, 'SGD 1_layer_1024': 0.29}

# %% [markdown]
# # <b>Модель 4</b> | Слои свертки

# %% [markdown]
# ## Модуль `tf.keras.applications` | `feature_extractor_layer`

# %% [markdown]
# Дополним существующую архитектуру слоями свертки и сжатия изображений и посмотрим, насколько изменится результат. Также добавим слои `dropout` и `batchnormalization`.

# %%
do_fine_tuning = False
feature_extractor = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet',
                                               # classes=num_classes
                                                     )
feature_extractor.trainable = do_fine_tuning

# %% [markdown]
# ## Архитектура модели

# %%
print(f'Строим модель на базе {MODULE_HANDLE}.')
print(f'Разморозка слоев: {do_fine_tuning}.\n')

model = tf.keras.Sequential([

            rescale,
            data_aug,

            feature_extractor,

            tf.keras.layers.Conv2D(32, (3, 3), padding="same",
                               strides=2, activation='relu'),
            tf.keras.layers.MaxPooling2D((2, 2)),
            tf.keras.layers.Conv2D(64, (3, 3), padding="same",
                               strides=2, activation='relu'),
            # tf.keras.layers.MaxPooling2D((2, 2)),

            tf.keras.layers.Flatten(),
            tf.keras.layers.Dropout(dropout),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(num_classes, activation='softmax')

], name='convnet_model')

model.build(input_shape=(None,) + IMAGE_SIZE + (3,))
model.summary()
# Out:
# Строим модель на базе tf.keras.applications.MobileNetV2.
# Разморозка слоев: False.
#
# Model: "convnet_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  sequential_1 (Sequential)   (None, 224, 224, 3)       0
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  conv2d_23 (Conv2D)          (None, 4, 4, 32)          368672
#
#  max_pooling2d_13 (MaxPoolin  (None, 2, 2, 32)         0
#  g2D)
#
#  conv2d_24 (Conv2D)          (None, 1, 1, 64)          18496
#
#  flatten_16 (Flatten)        (None, 64)                0
#
#  dropout_14 (Dropout)        (None, 64)                0
#
#  batch_normalization_14 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_26 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 2,645,733
# Trainable params: 387,621
# Non-trainable params: 2,258,112
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 8

# %% [markdown]
# ## Компиляция

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# ## Обучение модели

# %%
EPOCHS = 15

hist = model.fit(train_batches,
                 epochs=EPOCHS,
                 validation_data=validation_batches)
# Out:
# Epoch 1/15
# 34/34 [==============================] - 71s 2s/step - loss: 1.7079 - accuracy: 0.3296 - val_loss: 2.2441 - val_accuracy: 0.2893
# Epoch 2/15
# 34/34 [==============================] - 58s 2s/step - loss: 1.4723 - accuracy: 0.4176 - val_loss: 1.8625 - val_accuracy: 0.2642
# Epoch 3/15
# 34/34 [==============================] - 60s 2s/step - loss: 1.2983 - accuracy: 0.4935 - val_loss: 1.4661 - val_accuracy: 0.3899
# Epoch 4/15
# 34/34 [==============================] - 57s 2s/step - loss: 1.1978 - accuracy: 0.5231 - val_loss: 1.3851 - val_accuracy: 0.4654
# Epoch 5/15
# 34/34 [==============================] - 60s 2s/step - loss: 1.1289 - accuracy: 0.5565 - val_loss: 1.6501 - val_accuracy: 0.4151
# Epoch 6/15
# 34/34 [==============================] - 57s 2s/step - loss: 1.0881 - accuracy: 0.5769 - val_loss: 1.3348 - val_accuracy: 0.4277
# Epoch 7/15
# 34/34 [==============================] - 70s 2s/step - loss: 1.0678 - accuracy: 0.6083 - val_loss: 1.9261 - val_accuracy: 0.2956
# Epoch 8/15
# 34/34 [==============================] - 58s 2s/step - loss: 1.0623 - accuracy: 0.5833 - val_loss: 1.2125 - val_accuracy: 0.5786
# Epoch 9/15
# 34/34 [==============================] - 63s 2s/step - loss: 1.0035 - accuracy: 0.6250 - val_loss: 1.4864 - val_accuracy: 0.4088
# Epoch 10/15
# 34/34 [==============================] - 64s 2s/step - loss: 0.9888 - accuracy: 0.6222 - val_loss: 1.3212 - val_accuracy: 0.4843
# Epoch 11/15
# 34/34 [==============================] - 62s 2s/step - loss: 1.0362 - accuracy: 0.6037 - val_loss: 1.2860 - val_accuracy: 0.5094
# Epoch 12/15
# 34/34 [==============================] - 67s 2s/step - loss: 1.0253 - accuracy: 0.6009 - val_loss: 1.1935 - val_accuracy: 0.5283
# Epoch 13/15
# 34/34 [==============================] - 63s 2s/step - loss: 0.9866 - accuracy: 0.6315 - val_loss: 1.2076 - val_accuracy: 0.5094
# Epoch 14/15
# 34/34 [==============================] - 68s 2s/step - loss: 0.9632 - accuracy: 0.6370 - val_loss: 1.2285 - val_accuracy: 0.5031
# Epoch 15/15
# 34/34 [==============================] - 60s 2s/step - loss: 1.0041 - accuracy: 0.6278 - val_loss: 1.1764 - val_accuracy: 0.5409

# %% [markdown]
# ## Визуализация данных по работе алгоритма

# %%
val_acc_viz(hist, EPOCHS)

# %% [markdown]
# ## Предсказание модели

# %%
show_predictions(model)
# Out:
# joyfulness is joyfulness (50.46%)
# anger is disgust (28.32%)
# disgust is neutral (73.14%)
# neutral is neutral (65.20%)
# disgust is joyfulness (46.75%)
# neutral is neutral (43.82%)
# anger is joyfulness (46.27%)
# neutral is neutral (62.26%)
# neutral is neutral (75.10%)
# neutral is neutral (59.74%)

# %% [markdown]
# ## Матрица ошибок

# %%
confusion_matrix(model)

# %% [markdown]
# ## Вывод

# %% [markdown]
# Модель по-прежнему отрабатывает плохо - переобучение наступает до 10-й эпохи, предсказательная способность остается даже ниже, чем у второй модели. Продолжаем эксперимент.

# %%
val_acc_best = np.max(hist.history['val_accuracy'])
model_4_best_result = round(val_acc_best, 2)
model_4_best_result
# Out:
# 0.58

# %%
# сохраним данные о модели
model_4 = model
hist_4 = hist

# %% [markdown]
# # <b>Модель 5</b> | Больше слоёв классификатора

# %% [markdown]
# ## Модуль `tf.keras.applications` | `feature_extractor_layer`

# %% [markdown]
# Попробуем пойти вглубь и добавить полносвязных слоев.

# %%
do_fine_tuning = False
feature_extractor = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet',
                                               classes=num_classes)
feature_extractor.trainable = do_fine_tuning

# %% [markdown]
# ## Архитектура модели

# %%
print(f'Строим модель на базе {MODULE_HANDLE}.')
print(f'Разморозка слоев: {do_fine_tuning}.\n')

model = tf.keras.Sequential([

            rescale,
            data_aug,

            feature_extractor,

            tf.keras.layers.Conv2D(32, (3, 3), padding="same",
                               strides=1, activation='relu'),
            tf.keras.layers.MaxPooling2D((2, 2)),
            tf.keras.layers.Conv2D(64, (3, 3), padding="same",
                               strides=1, activation='relu'),

            tf.keras.layers.Flatten(),

            tf.keras.layers.Dropout(dropout),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(512, activation='relu'),

            tf.keras.layers.Dropout(dropout),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(512, activation='relu'),

            tf.keras.layers.Dropout(dropout),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(num_classes, activation='softmax')

], name='convnet__wider_model')

model.build(input_shape=(None,) + IMAGE_SIZE + (3,))
model.summary()
# Out:
# Строим модель на базе tf.keras.applications.MobileNetV2.
# Разморозка слоев: False.
#
# Model: "convnet__wider_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  sequential_1 (Sequential)   (None, 224, 224, 3)       0
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  conv2d_14 (Conv2D)          (None, 7, 7, 32)          368672
#
#  max_pooling2d_7 (MaxPooling  (None, 3, 3, 32)         0
#  2D)
#
#  conv2d_15 (Conv2D)          (None, 3, 3, 64)          18496
#
#  flatten_10 (Flatten)        (None, 576)               0
#
#  dropout_8 (Dropout)         (None, 576)               0
#
#  batch_normalization_8 (Batc  (None, 576)              2304
#  hNormalization)
#
#  dense_18 (Dense)            (None, 512)               295424
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  batch_normalization_9 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_19 (Dense)            (None, 512)               262656
#
#  dropout_10 (Dropout)        (None, 512)               0
#
#  batch_normalization_10 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_20 (Dense)            (None, 5)                 2565
#
# =================================================================
# Total params: 3,212,197
# Trainable params: 951,013
# Non-trainable params: 2,261,184
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 16

# %% [markdown]
# ## Компиляция

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# ## Обучение модели

# %%
EPOCHS = 15

hist = model.fit(train_batches,
                 epochs=EPOCHS,
                 validation_data=validation_batches)
# Out:
# Epoch 1/15
# 34/34 [==============================] - 71s 2s/step - loss: 2.1642 - accuracy: 0.2481 - val_loss: 1.8232 - val_accuracy: 0.3459
# Epoch 2/15
# 34/34 [==============================] - 54s 2s/step - loss: 1.9446 - accuracy: 0.2963 - val_loss: 2.3612 - val_accuracy: 0.2516
# Epoch 3/15
# 34/34 [==============================] - 61s 2s/step - loss: 1.7900 - accuracy: 0.3611 - val_loss: 2.0003 - val_accuracy: 0.2956
# Epoch 4/15
# 34/34 [==============================] - 54s 2s/step - loss: 1.6719 - accuracy: 0.3926 - val_loss: 2.0597 - val_accuracy: 0.2956
# Epoch 5/15
# 34/34 [==============================] - 61s 2s/step - loss: 1.5167 - accuracy: 0.4481 - val_loss: 1.5672 - val_accuracy: 0.3899
# Epoch 6/15
# 34/34 [==============================] - 56s 2s/step - loss: 1.4289 - accuracy: 0.4528 - val_loss: 1.6072 - val_accuracy: 0.4151
# Epoch 7/15
# 34/34 [==============================] - 58s 2s/step - loss: 1.3578 - accuracy: 0.4954 - val_loss: 2.0347 - val_accuracy: 0.3145
# Epoch 8/15
# 34/34 [==============================] - 57s 2s/step - loss: 1.3174 - accuracy: 0.5139 - val_loss: 1.4048 - val_accuracy: 0.4340
# Epoch 9/15
# 34/34 [==============================] - 55s 2s/step - loss: 1.2426 - accuracy: 0.5361 - val_loss: 1.3651 - val_accuracy: 0.4465
# Epoch 10/15
# 34/34 [==============================] - 60s 2s/step - loss: 1.2399 - accuracy: 0.5444 - val_loss: 1.3775 - val_accuracy: 0.3962
# Epoch 11/15
# 34/34 [==============================] - 54s 2s/step - loss: 1.2133 - accuracy: 0.5417 - val_loss: 1.4303 - val_accuracy: 0.4088
# Epoch 12/15
# 34/34 [==============================] - 61s 2s/step - loss: 1.1971 - accuracy: 0.5593 - val_loss: 1.6253 - val_accuracy: 0.4025
# Epoch 13/15
# 34/34 [==============================] - 55s 2s/step - loss: 1.1148 - accuracy: 0.5741 - val_loss: 1.5109 - val_accuracy: 0.4214
# Epoch 14/15
# 34/34 [==============================] - 61s 2s/step - loss: 1.1139 - accuracy: 0.5685 - val_loss: 1.8261 - val_accuracy: 0.3774
# Epoch 15/15
# 34/34 [==============================] - 53s 2s/step - loss: 1.0889 - accuracy: 0.5935 - val_loss: 1.2751 - val_accuracy: 0.5094

# %% [markdown]
# ## Визуализация данных по работе алгоритма

# %%
val_acc_viz(hist, EPOCHS)

# %% [markdown]
# ## Предсказание модели

# %%
show_predictions(model)
# Out:
# neutral is neutral (82.95%)
# joyfulness is disgust (34.02%)
# neutral is neutral (84.58%)
# neutral is neutral (80.06%)
# neutral is fear (49.44%)
# fear is fear (87.75%)
# neutral is neutral (62.91%)
# disgust is neutral (39.37%)
# fear is neutral (53.79%)
# disgust is neutral (74.56%)

# %% [markdown]
# ## Матрица ошибок

# %%
confusion_matrix(model)

# %% [markdown]
# ## Вывод

# %% [markdown]
# Модель по-прежнему отрабатывает плохо - переобучение наступает до 10-й эпохи, предсказательная способность остается даже ниже, чем у второй модели. Продолжаем эксперимент.

# %%
val_acc_best = np.max(hist.history['val_accuracy'])
model_5_best_result = round(val_acc_best, 2)
model_5_best_result
# Out:
# 0.51

# %%
# сохраним данные о модели
model_5 = model
hist_5 = hist

# %% [markdown]
# # <b>Модель 6</b> | `fine_tuning`

# %% [markdown]
# ## Модуль `tf.keras.applications` | `feature_extractor_layer`

# %% [markdown]
# На следующем шаге проверим эту же модель, но разморозим часть слоев предобученной модели. В официальных документах указано, что размораживать слои следует только после того, как мы уже обучили собственный классификатор, в ином случае предобученная модель с установленными в случайном порядке весами для новых слоев при обновлении весов потеряет все, чему она была обучена.
#
# Кроме того, нет необходимости в разморозке "нижних слоев", так как они обнаруживают самые простые и общие закономерности, характерные для любых изображений. Цель применения предобученной модели - использовать более "специализированные" слои для дообучения новой модели на новом датасете, поэтому возьмем сравнительно небольшое число "верхних" слоев.
#
# Особого внимания в случае разморозки `feature_extractor` заслуживают слои bacth normalization (`BN`). Это единственные встроенные слои, веса которых не должны обновляться при градиентном спуске, так как эти веса - движущиеся среднее значение и стандартное отклонение для нормализации текущего батча. Запустив модель в режиме `trainable=False`, мы эти слои заморозили. Когда мы на следующем шаге размораживаем всю модель или ее часть, слои BN продолжают работать в режиме inference (движущиеся mean и std), а не обучения (mean и std текущего батча). Это очень важный момент, так как если мы запустим `feature_extractor` сразу в режиме разморозки без предварительного обучения на замороженных слоях (то есть не заморозим веса BN), слои BN будут давать непредсказуемый результат (подробнее о проблеме [здесь](https://keras.io/getting_started/faq/#whats-the-difference-between-the-training-argument-in-call-and-the-trainable-attribute)).

# %%
do_fine_tuning = True
feature_extractor = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
feature_extractor.trainable = do_fine_tuning

print(f'Разморозка слоев: {do_fine_tuning}.')
# Out:
# Разморозка слоев: True.

# %% [markdown]
# Посмотрим на количество слоев в предобученной модели:

# %%
print("Number of layers in the feature extractor: ", len(feature_extractor.layers))
print("Trainable layers in the feature extractor: ", len(feature_extractor.trainable_variables))
# Out:
# Number of layers in the feature extractor:  154
# Trainable layers in the feature extractor:  54

# %%
# с какого слоя мы размораживаем модель
fine_tune_at = 100

# Заморозим все остальные слои
for layer in feature_extractor.layers[:fine_tune_at]:
    layer.trainable = False

# %% [markdown]
# ## Компиляция

# %% [markdown]
# Теперь необходимо скомпилировать нашу уже обученную на предыдущем этапе модель, чтобы изменения были применены.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# ## Архитектура модели

# %%
model.summary()
# Out:
# Model: "baseline"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  flatten_2 (Flatten)         (None, 62720)             0
#
#  dropout_3 (Dropout)         (None, 62720)             0
#
#  dense_3 (Dense)             (None, 5)                 313605
#
# =================================================================
# Total params: 2,571,589
# Trainable params: 313,605
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 2

# %% [markdown]
# Итак, у нашей модели 2 переменные, которые будут обучаться - это переменные с весами и свободными членами.

# %% [markdown]
# ## Обучение модели

# %%
EPOCHS = 15

hist = model.fit(train_batches,
                 epochs=EPOCHS,
                 validation_data=validation_batches,
                 )

# %% [markdown]
# # <b>Модель 7</b> | Финальная модель

# %% [markdown]
# Финальная модель будет состоять из двух частей:
# - обучение классификатора на предобученой модели с замороженными слоями,
# - дообучение классификатора на размороженных слоях.
